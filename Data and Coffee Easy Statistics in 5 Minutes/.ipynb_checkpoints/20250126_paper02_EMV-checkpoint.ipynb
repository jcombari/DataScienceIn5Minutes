# %% [markdown]
# ## 📊☕ Data & Coffee: Statistics Made Simple in 5 Minutes
#
# ### ❓ Did you know the maximum likelihood estimator has revolutionized how we analyze data in science and business?
# 🙃 Ronald Fisher introduced it in his iconic 1922 paper, and it remains essential today!
#
# ### 🔧 How does it work?
# The maximum likelihood estimator helps us find the parameters that best explain a dataset. Simply put, it identifies values that maximize the probability of observing our data. It works with quantitative data and is crucial in fields like machine learning.
#
# ### 🔎 Why does it matter?
# - 📌 Its statistical efficiency and precision make it a cornerstone of model estimation.
# - 📌 Applications range from risk analysis and predictive marketing to search engine optimization.
#
# ### ✨ Practical example:
# Let’s use the Iris dataset (included in Python). We’ll fit a model using maximum likelihood to classify flower species. The example includes an interactive plot visualizing probability distributions.
#
# ### ⚙️ Business impact:
# - ✔️ Optimizes predictions in recommendation systems.
# - ✔️ Enhances models in credit analysis and customer segmentation.
#
# ### 📊 Code summary:
# The code leverages scikit-learn to train a classification model based on maximum likelihood and visualize results. The Iris dataset contains real-world data about three flower species, with features like petal and sepal lengths. This example bridges theoretical concepts with practical solutions.
#
# ### ✦✧ What do we achieve?
# We visualize the model's accuracy and understand how data distributions affect predictions. This example turns theory into actionable insights for the industry.
#
# ### 📖✍️ Paper details:
# - **Title**: On the Mathematical Foundations of Theoretical Statistics
# - **Author**: Ronald A. Fisher
# - **Publication**: Philosophical Transactions of the Royal Society A, 1922
# - [Access the paper here](https://www.jstor.org/stable/40445793)
#
# ### 💭 Reflection:
# Statistics might seem complex, but the right tools turn ideas into action. How would you use this technique in your field? Share your thoughts below! 🌟
#
# [Enlace a GitHub](https://github.com/jcombari/DataScienceIn5Minutes/tree/main/Data%20and%20Coffee%20Easy%20Statistics%20in%205%20Minutes)
#
# 🌍✨ #DataScience #MachineLearning #Statistics #ArtificialIntelligence #AI #DataVisualization
#
# ---
#
# # 📊☕ Datos y Café: Estadística Fácil en 5 Minutos
#
# ## ❓ ¿Sabías que el concepto de estimador de máxima verosimilitud ha transformado la forma en que analizamos datos en ciencia y negocios?
# 🙃 Ronald Fisher lo introdujo en su icónico artículo de 1922, ¡y sigue siendo una herramienta esencial hoy en día!
#
# ### 🔧 ¿Cómo funciona?
# El estimador de máxima verosimilitud nos permite encontrar los parámetros que mejor explican un conjunto de datos. En términos simples: buscamos los valores que maximizan la probabilidad de que nuestros datos sean lo que son. Funciona con datos cuantitativos y es fundamental en áreas como el aprendizaje automático.
#
# ### 🔎 ¿Por qué importa?
# - 📌 La eficiencia estadística y precisión de este enfoque lo convierten en un pilar en la estimación de modelos.
# - 📌 Se aplica en análisis de riesgos, marketing predictivo y optimización de motores de búsqueda.
#
# ### ✨ Ejemplo práctico:
# Tomemos el dataset Iris (incluido en Python). Analizaremos cómo ajustar un modelo utilizando máxima verosimilitud para clasificar especies de flores. El ejemplo incluye un gráfico interactivo para visualizar la distribución de las probabilidades.
#
# ### ⚙️ Impacto en el negocio:
# - ✔️ Optimiza predicciones en sistemas de recomendación.
# - ✔️ Mejora modelos en análisis de crédito y segmentación de clientes.
#
# ### 📊 Resumen del código:
# El código utiliza la librería scikit-learn para entrenar un modelo de clasificación basado en máxima verosimilitud y visualizar los resultados. El dataset Iris incluye datos reales sobre tres especies de flores, con medidas como longitud de pétalos y sépalos. Este ejemplo muestra cómo aplicar el concepto en clasificación y análisis de datos.
#
# ### ✦✧ ¿Qué obtenemos?
# Visualizamos la precisión del modelo y comprendemos cómo las distribuciones de datos afectan las predicciones. Este ejemplo traduce un concepto teórico en soluciones prácticas para la industria.
#
# ### 📖✍️ Datos del paper:
# - **Título**: On the Mathematical Foundations of Theoretical Statistics
# - **Autor**: Ronald A. Fisher
# - **Publicación**: Philosophical Transactions of the Royal Society A, 1922
# - [Acceso al artículo aquí](https://www.jstor.org/stable/40445793)
#
# ### 💭 Reflexión:
# La estadística puede parecer compleja, pero con las herramientas adecuadas podemos transformar ideas en acciones. ¿Qué otras aplicaciones se te ocurren para esta técnica en tu campo? ¡Comenta abajo! 🌟
#
# [Enlace a GitHub](https://github.com/jcombari/DataScienceIn5Minutes/tree/main/Data%20and%20Coffee%20Easy%20Statistics%20in%205%20Minutes)
#
# 🌍✨ #CienciaDeDatos #AprendizajeAutomático #Estadística #InteligenciaArtificial #MachineLearning #DataScience

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Iris dataset
iris = load_iris()
data = pd.DataFrame(data=np.c_[iris['data'], iris['target']], columns=iris['feature_names'] + ['target'])

# Split dataset into training and testing sets
X = data.iloc[:, :-1]  # Features: sepal and petal dimensions
y = data['target']     # Target: flower species
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a logistic regression model (maximum likelihood method)
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))

# Plot the results
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_test.iloc[:, 2], y=X_test.iloc[:, 3], hue=y_test, style=y_pred, palette='viridis', s=100)
plt.title("Logistic Regression Predictions (Iris Dataset)")
plt.xlabel("Petal length (cm)")
plt.ylabel("Petal width (cm)")
plt.legend(title="Flower Species")
plt.grid(True)
plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        19
#          1.0       1.00      1.00      1.00        13
#          2.0       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# Accuracy Score: 1.0
