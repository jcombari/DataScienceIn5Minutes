# %% [markdown]
# # 🔗🐍📊 Bridging Python & R: Seamless Data Science in 5 Minutes
#
# ## 🐍📘📊 Python | R: Meteor Shower Visualization with `geom_point` and `scatterplot`
#
# ### ✨ Did you know you can visualize a meteor shower with just data? 🌌
# You don’t need a telescope to explore the cosmos — just a bit of creativity and a good dataset.
# Let’s use a classic earthquake dataset to simulate a cosmic phenomenon. 🌠
#
# ### 👉 The solution
# 📍 Today, we’ll use the R `quakes` dataset to simulate and visualize a "meteor shower"
# 🎯 We'll build matching visualizations in both Python 🐍 and R 📘 using the same logic.
#
# ### 🔧 How it works
# 💾 The `quakes` dataset includes location and depth of earthquakes — we'll treat them as "meteor impacts."
# 📊 We plot latitude vs longitude and use depth as point size — like shining stars in the data sky.
#
# ### 🔎 Why it matters
# 💥 Repurposing classic datasets teaches creativity in data storytelling.
# 🎨 Ideal for scientific dashboards, education, and visual communication of natural phenomena.
#
# ### ✨ Real-life application:
# 🚀 Imagine working in space outreach and needing a public-friendly meteor data map.
# 🎤 This kind of plot makes complex patterns intuitive and engaging.
#
# ### ⚙️ Business impact
# 🧠 Helps data teams tell their stories visually.
# 📢 Perfect for science marketing, media reporting, or educational content.
# 📉 Drives better decision-making by simplifying complex data visually.
#
# ### 📊 Code summary
# ☄️ We use the `quakes` dataset and plot latitude vs longitude.
# 🔵 In Python: we use `matplotlib` and `seaborn`.
# 🔵 In R: we use `ggplot2`.
# 📍 Point size reflects depth, enhancing the “meteor impact” effect.
#
# 🔗[Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# 💭 Reflection
# 💬 In an age of info overload, turning data into stories is a superpower.
# 🌌 What dataset would you turn into a visual story?
#
# 🔑 #DataScience #DataVisualization #Python #RStats #MeteorShowers #AI #Storytelling #MachineLearning #ScienceEducation #DataStorytelling #PythonVsR #DeepLearning #SpaceData #ScienceComm #GenerativeAI #LinkedInGrowth #CareerBoost #WomenInTech #CloudComputing #PromptEngineering #AWS #Agile #Neurodiversity
#
#
# ---
#
# # 🔗🐍📊 Bridging Python & R: Seamless Data Science in 5 Minutes
#
# ## 🐍📘📊 Python | R: Visualización de lluvias de meteoros con `geom_point` y `scatterplot`
#
# ### ✨ Lluvia de estrellas... ¡con datos! 🌠
# ¿Sabías que puedes analizar lluvias de meteoros con herramientas de ciencia de datos sin necesidad de un telescopio?
# ¡Los datos astronómicos también brillan si sabes cómo graficarlos! 💡
#
# ### 👉 Solución
# 📍 Hoy te muestro cómo visualizar patrones astronómicos con un dataset clásico de meteoros (`quakes`)
# 🎯 Compararemos cómo hacer esto en Python 🐍 y R 📘 con resultados idénticos y visuales claros.
#
# ### 🔧 ¿Cómo funciona?
# 💾 Usamos el dataset `quakes` de R, que contiene datos de terremotos, pero simulamos una "lluvia de meteoros" cambiando el contexto.
# 📊 Visualizamos la ubicación (latitud, longitud) y la profundidad como tamaño de punto — ¡como si fueran estrellas en el cielo!
#
# ### 🔎 ¿Por qué importa?
# 💥 Aprender a reutilizar datasets clásicos para fines creativos abre la mente y desarrolla habilidades cruciales en storytelling de datos.
# 🎨 Esta visualización es ideal para dashboards científicos, educación o comunicación visual de fenómenos naturales.
#
# ### ✨ Ejemplo real o Caso práctico:
# 🚀 Imagina que eres parte del equipo de comunicación científica de una agencia espacial.
# 🎤 Necesitas mostrar en redes un mapa de lluvias de meteoros basándote en datos históricos.
# ✅ Este enfoque permite representar eventos de alto impacto de forma clara, atractiva y técnica.
#
# ### ⚙️ Impacto en el negocio:
# 🧠 Hace que los equipos de ciencia de datos comuniquen mejor sus hallazgos.
# 📢 Ideal para marketing científico, divulgación, presentaciones de impacto o reportes interactivos.
# 📉 Mejora la toma de decisiones al transformar eventos complejos en visualizaciones intuitivas.
#
# ### 📊 Resumen de qué se hace en el código
# ☄️ Cargamos el dataset `quakes` y graficamos latitud vs longitud.
# 🔵 En Python: usamos `matplotlib` y `seaborn`.
# 🔵 En R: usamos `ggplot2`.
# 📍 El tamaño del punto representa la profundidad, como si fuera la intensidad visual de una estrella.
#
# 🔗[Github](https://github.com/jcombari/AI-For-Unstructured-Data/tree/main)
#
# 💭 Reflexión:
# 💬 En un mundo saturado de información, la capacidad de transformar datos en historias visuales es una superpotencia.
# 🌌 ¿Y tú? ¿Cómo transformarías un conjunto de datos clásico en una visualización inesperada?
#
# 🔑 #DataScience #VisualizaciónDeDatos #Python #RStats #Meteoros #IA #Storytelling #MachineLearning #EducaciónCientífica #DataStorytelling #PythonVsR #DeepLearning #CienciaDeDatos #DivulgaciónCientífica #AI #GenerativeAI #LinkedInTips #OpenToWork #TechForGood #Cloud #Neurodiversidad #PromptEngineering #AWS #Agile #CareerGrowth
#
# ---
# ![image.png](attachment:8a0c2edc-26c3-4fe4-994e-fa4e82f2f76e.png)

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Simulate a dataset similar to R's quakes
np.random.seed(42)
data = pd.DataFrame({
    "lat": np.random.uniform(-38.5, -17.5, 1000),  # latitude range
    "long": np.random.uniform(165, 190, 1000),     # longitude range
    "depth": np.random.uniform(0, 700, 1000)       # depth range
})

# Create scatter plot using longitude and latitude
plt.figure(figsize=(10, 6))
scatter = plt.scatter(data["long"], data["lat"], c=data["depth"], cmap='viridis', s=data["depth"] / 2, alpha=0.6)
plt.colorbar(scatter, label='Depth (km)')  # Add color bar for depth
plt.title("Simulated Meteor Shower (Earthquake Data)")  # Title for the plot
plt.xlabel("Longitude")  # X-axis label
plt.ylabel("Latitude")  # Y-axis label
plt.grid(True)  # Show grid for better readability
plt.show()  # Display the plot

# %%
# Load necessary libraries
suppressWarnings(library(ggplot2))

# Load the built-in 'quakes' dataset
data("quakes")

# Create a scatter plot: longitude vs latitude, point size by depth
ggplot(quakes, aes(x = long, y = lat)) +
  geom_point(aes(size = depth, color = depth), alpha = 0.6) +  # Set point size and color by depth
  scale_color_viridis_c() +  # Use a color scale (viridis)
  labs(
    title = "Meteor Shower Simulation with Earthquake Data",  # Title of the plot
    x = "Longitude",  # X-axis label
    y = "Latitude",   # Y-axis label
    color = "Depth (km)",  # Color label for depth
    size = "Depth (km)"    # Size label for depth
  ) +
  theme_minimal()  # Use a minimal theme for a clean look
# Out:
# plot without title
