# %% [markdown]
# # ✨ Mathematical Poetry Day - March 21st ✨
#
# ## ❓ Did you know that the words in poems can also be analyzed mathematically?
# 🙃 Let’s visualize the most common words in the mathematical poems of Omar Khayyam, a Persian mathematician, astronomer, and poet, using word clouds! With this technique, you’ll be able to integrate creativity into your data science projects in a unique way. 🌟
#
# ## 👉 Solution
# We will use word clouds to extract the key words from Khayyam’s mathematical poems and visualize them, using both Python and R. Text processing models in data science can be a powerful ally when analyzing large amounts of textual information, and word cloud visualization can help you understand what concepts dominate a text, which is crucial in fields like sentiment analysis and text mining. 🚀
#
# ## 🔧 How does it work?
# 1. We extract the most frequent words from a text (in this case, *Rubaiyat* by Khayyam).
# 2. We visualize them in a **word cloud**, where the size of each word represents its frequency.
# 3. Both Python and R can accomplish this task efficiently, though each language has its unique tools for doing so.
#
# ## 🔎 Why does it matter?
# Word clouds are an excellent way to transform complex textual information into something visually accessible. This technique can help you identify patterns and discover what truly matters in large volumes of textual data! 🌐
#
# ## ✨ Real-world example or case study
# Imagine you’re working on a project where you need to analyze customer feedback about your product. You can apply the same approach to identify the most relevant terms used by customers and visualize them in a way that makes it easy for your team to spot key words or phrases.
#
# ## ⚙️ Impact on business
# ✅ **Resource optimization:** Helps quickly identify words or themes that most impact your product or service.
# ✅ **Better decision-making:** Makes it easier to understand large volumes of text, which is valuable for sentiment analysis or customer service projects.
#
# ## 📊 Summary of what the code does
# 📌 The code takes the text from *Rubaiyat*, processes it to count the most frequent words, and then visualizes them in a word cloud. It’s a simple yet powerful approach to quickly grasp the frequency of words in any textual dataset. 🔍
#
# 🔗 📌 GitHub: [Bridging Python & R: Seamless Data Science in 5 Minutes ](https://github.com/jcombari/DataScienceIn5Minutes/tree/main/Bridging%20Python%20%26%20R%20Data%20Science%20in%205%20Minutes).
#
# ## 💭 Reflection
# How would you approach this problem in your day-to-day work? Would you like to explore how word clouds can help you understand your data in a more visual way? I’m here to help! 🌍
#
# 🔑 #DataScience #MachineLearning #R #Python #TextMining #WordCloud #AI #DataVisualization #TechForAll #Neurodiversity #WomenInTech #GenerativeAI
#
# ---
#
# # ✨ Día de la poesía matemática - 21 de marzo ✨
#
# ## ❓ ¿Sabías que las palabras de los poemas también pueden ser analizadas matemáticamente?
# 🙃 ¡Vamos a visualizar las palabras más comunes de los poemas de Omar Khayyam, un matemático, astrónomo y poeta persa, usando nubes de palabras! Con esta técnica, podrás integrar la creatividad en tus proyectos de ciencia de datos de manera única. 🌟
#
# ## 👉 Solución
# Usaremos nubes de palabras para extraer las palabras clave de los poemas matemáticos de Khayyam y visualizarlas, utilizando tanto Python como R. Los modelos de procesamiento de texto en la ciencia de datos pueden ser un poderoso aliado para analizar grandes volúmenes de información textual, y la visualización de nubes de palabras puede ayudarte a comprender qué conceptos dominan un texto, algo esencial en áreas como análisis de sentimientos y minería de texto. 🚀
#
# ## 🔧 ¿Cómo funciona?
# 1. Extraemos las palabras más frecuentes de un texto (en este caso, el *Rubaiyat* de Khayyam).
# 2. Las visualizamos en una **nube de palabras**, donde el tamaño de cada palabra representa su frecuencia.
# 3. Tanto en Python como en R, realizamos este proceso de manera muy eficiente, pero cada lenguaje tiene sus herramientas únicas para hacerlo.
#
# ## 🔎 ¿Por qué importa?
# Las nubes de palabras son una excelente manera de transformar información textual compleja en algo visualmente accesible. ¡Esta técnica puede ayudarte a identificar patrones y descubrir lo que realmente importa en grandes volúmenes de datos textuales! 🌐
#
# ## ✨ Ejemplo real o caso práctico
# Imagina que estás trabajando en un proyecto donde necesitas analizar opiniones de clientes sobre tu producto. Puedes aplicar este mismo enfoque para identificar los términos más relevantes que utilizan los clientes y visualizarlos de manera que todos los miembros del equipo puedan ver claramente las palabras o frases clave.
#
# ## ⚙️ Impacto en el negocio
# ✅ **Optimización de recursos:** Ayuda a identificar rápidamente las palabras o temas que más afectan a tu producto o servicio.
# ✅ **Mejora de la toma de decisiones:** Facilita la comprensión de grandes volúmenes de texto, lo cual es útil para proyectos de análisis de sentimiento o atención al cliente.
#
# ## 📊 Resumen de qué se hace en el código
# 📌 El código toma el texto de la obra *Rubaiyat*, lo procesa para contar las palabras más frecuentes y luego las visualiza en una nube de palabras. Es un enfoque simple pero poderoso para entender rápidamente la frecuencia de las palabras en cualquier conjunto de datos textuales. 🔍
#
# 🔗 📌 GitHub: [Bridging Python & R: Seamless Data Science in 5 Minutes ](https://github.com/jcombari/DataScienceIn5Minutes/tree/main/Bridging%20Python%20%26%20R%20Data%20Science%20in%205%20Minutes).
#
# ## 💭 Reflexión
# ¿Cómo abordarías este problema en tu día a día? ¿Te gustaría explorar cómo las nubes de palabras pueden ayudarte a entender tus datos de manera más visual? ¡Estoy aquí para ayudarte! 🌍
#
# 🔑 #DataScience #MachineLearning #R #Python #TextMining #WordCloud #AI #DataVisualization #TechForAll #Neurodiversity #WomenInTech #GenerativeAI

# %% [markdown]
# # 🐍 Python Code

# %%
# Install and load necessary packages (only if they are not installed)
try:
    import nltk
    from wordcloud import WordCloud
    import matplotlib.pyplot as plt
    import pandas as pd
    from nltk.corpus import stopwords
    from nltk.tokenize import word_tokenize
    import string
except ImportError:
    print("Some packages are not installed. Installing them...")
    !pip install nltk wordcloud matplotlib pandas

# Disable NLTK download messages
import logging
logging.getLogger('nltk').setLevel(logging.CRITICAL)

# Download NLTK resources without showing download messages
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)

# Define the sample text to be analyzed
text = """
If I confide my secrets to you in a dive, that's better than to pray without you in a shrine...
Knock off your scheming and your boastful tales; if possible, avoid upbraiding drunks. If from now on you want a peaceful life, Do not ill-treat the lowest of the low.
Rein in yourself and don't cut others down; don't blister people in your anger's flames. If you have hopes for everlasting rest, Yes, feel the pain but don't lash out in rage.
Since we can't trust tomorrow, find a way to fill this lovelorn heart with joy: Drink up in the light of the moon-- a moon that someday will look for us ... and not find us.
They call the scriptures the exalted word, but they recite them once in a long while.
The label on a vessel of red wine- now that they're always reading out aloud.
Here we shiver on stools with our wine and that broken-down old stove. We've lost all hope of mercy, and all fear of torment. Soul and heart, cup and cloak-all a sacrifice for that one drink.
If you could look with wisdom's eye you'd see: The person that you count on is your foe. It's better in these days to make few friends, and always keep your distance when you speak.
This clay mug once longed, like me-a heartsick lover- for his beloved's face.
Too bad if your heart isn't scorched, if there's no one you're pining for, who makes it leap. That day on which love does not ache in you is the most wasted day of your whole life.
A book of poetry, some ruby wine, and you, and half a loaf of bread-I don't need any more; when you and I are curled up in the great outdoors, our bliss outshines the glories of an emperor.
Don't give way to fruitless heartache-be happy! Although you walk an unfair path, live justly. For in the end this world is nothingness.
Whenever I look, in whichever direction, a stream from eternity flows into my garden. The desert is like heaven now, since hell's gone missing. Sit in paradise next to a beauty with the face of an angel!
Be glad, they grew your profits yesterday: Your hopes and dreams came true in every way. Live happily, since yesterday, before you asked, they set tomorrow's fate for you.
Pour me a tulip-red nectar and spill the bottle's blood from its long throat- because today, save for my cup of wine, I have no friend with inner purity.
The turning heavens whispered secretly in my heart's ear: 'You know from me the command that was decreed.' But if I were given a free hand as I went round and round, I'd save myself from this vertigo.
If we could find a little loaf of bread, and get hold of a roast of lamb and wine, and we were snuggling in the wilderness- we'd put to shame the pomp of any court.
If that day comes when you acquire a crate of wine- drink up at every banquet, every gathering! Because the one who made the world could not care less, if I should wear a moustache or you sport a beard.
If I had a choice of whether to be born, I wouldn't have come. But likewise, if I had the choice to die, when would I do that? Given that this world is dust, wouldn't it have been better had I never been born, or died, or ever was?
The time of fasting has passed, and good times are here again- the time to raise a bottle high. Don't worry, the porters are bringing more!
"""

# Convert the text into a list of words
tokens = word_tokenize(text.lower())

# Remove punctuation and empty words (stopwords)
tokens = [word for word in tokens if word not in string.punctuation]

# Load the stopwords in English
stop_words = set(stopwords.words("english"))

# Filter out stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]

# Count word frequencies
word_freq = pd.Series(filtered_tokens).value_counts()

# Create the word frequency table
word_freq_table = word_freq.reset_index()
word_freq_table.columns = ["word", "freq"]

# Create the word cloud (WordCloud) with a vintage color palette
wordcloud = WordCloud(
    width=800, height=400,
    background_color="white",
    colormap="copper",  # Use a vintage color map
    max_words=100,
    min_font_size=10
).generate_from_frequencies(word_freq.to_dict())

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Hide the axes
plt.show()

# %% [markdown]
# # 📘 R Code

# %%
# Install and load necessary packages (only if they are not already installed)
if (!require(tm)) {  # Check if the "tm" package (for text mining) is installed
  install.packages("tm")  # Install "tm" package if not installed
  library(tm)  # Load the "tm" package
}

if (!require(wordcloud)) {  # Check if the "wordcloud" package (for visualization) is installed
  install.packages("wordcloud")  # Install "wordcloud" package if not installed
  library(wordcloud)  # Load the "wordcloud" package
}

if (!require(RColorBrewer)) {  # Check if the "RColorBrewer" package (for color palettes) is installed
  install.packages("RColorBrewer")  # Install "RColorBrewer" package if not installed
  library(RColorBrewer)  # Load the "RColorBrewer" package
}

suppressWarnings(library(tm))
suppressWarnings(library(wordcloud))
suppressWarnings(library(RColorBrewer))

# Define a sample text to be analyzed
text <- "If I confide my secrets to you in a dive, that's better than to pray without you in a shrine...
Knock off your scheming and your boastful tales; if possible, avoid upbraiding drunks. If from now on you want a peaceful life, Do not ill-treat the lowest of the low.
Rein in yourself and don't cut others down; don't blister people in your anger's flames. If you have hopes for everlasting rest, Yes, feel the pain but don't lash out in rage.
Since we can't trust tomorrow, find a way to fill this lovelorn heart with joy: Drink up in the light of the moon-- a moon that someday will look for us ... and not find us.
They call the scriptures the exalted word, but they recite them once in a long while.
The label on a vessel of red wine- now that they're always reading out aloud.
Here we shiver on stools with our wine and that broken-down old stove. We've lost all hope of mercy, and all fear of torment. Soul and heart, cup and cloak-all a sacrifice for that one drink.
If you could look with wisdom's eye you'd see: The person that you count on is your foe. It's better in these days to make few friends, and always keep your distance when you speak.
This clay mug once longed, like me-a heartsick lover- for his beloved's face.
Too bad if your heart isn't scorched, if there's no one you're pining for, who makes it leap. That day on which love does not ache in you is the most wasted day of your whole life.
A book of poetry, some ruby wine, and you, and half a loaf of bread-I don't need any more; when you and I are curled up in the great outdoors, our bliss outshines the glories of an emperor.
Don't give way to fruitless heartache-be happy! Although you walk an unfair path, live justly. For in the end this world is nothingness.
Whenever I look, in whichever direction, a stream from eternity flows into my garden. The desert is like heaven now, since hell's gone missing. Sit in paradise next to a beauty with the face of an angel!
Be glad, they grew your profits yesterday: Your hopes and dreams came true in every way. Live happily, since yesterday, before you asked, they set tomorrow's fate for you.
Pour me a tulip-red nectar and spill the bottle's blood from its long throat- because today, save for my cup of wine, I have no friend with inner purity.
The turning heavens whispered secretly in my heart's ear: 'You know from me the command that was decreed.' But if I were given a free hand as I went round and round, I'd save myself from this vertigo.
If we could find a little loaf of bread, and get hold of a roast of lamb and wine, and we were snuggling in the wilderness- we'd put to shame the pomp of any court.
If that day comes when you acquire a crate of wine- drink up at every banquet, every gathering! Because the one who made the world could not care less, if I should wear a moustache or you sport a beard.
If I had a choice of whether to be born, I wouldn't have come. But likewise, if I had the choice to die, when would I do that? Given that this world is dust, wouldn't it have been better had I never been born, or died, or ever was?
The time of fasting has passed, and good times are here again- the time to raise a bottle high. Don't worry, the porters are bringing more!"

# Convert the sample text into a text corpus (a structured format for text processing)
corpus <- Corpus(VectorSource(text))

# Custom function to clean the text corpus
clean_corpus <- function(corpus) {
  # Convert text to lowercase to standardize word representation
  corpus <- suppressWarnings(tm_map(corpus, content_transformer(tolower)))
  
  # Remove punctuation to eliminate unnecessary symbols
  corpus <- suppressWarnings(tm_map(corpus, removePunctuation))
  
  # Remove numbers since they do not contribute to word analysis
  corpus <- suppressWarnings(tm_map(corpus, removeNumbers))
  
  # Remove common stopwords (e.g., "the", "and", "is") to focus on meaningful words
  corpus <- suppressWarnings(tm_map(corpus, removeWords, stopwords("en")))
  
  # Remove empty documents (documents that have no content after transformations)
  corpus <- corpus[sapply(corpus, function(x) nchar(as.character(x)) > 0)]
  
  return(corpus)  # Return the cleaned corpus
}

# Apply text cleaning function to the corpus
corpus <- clean_corpus(corpus)

# Create a Term-Document Matrix (TDM) 
# This matrix represents word frequencies across documents
dtm <- TermDocumentMatrix(corpus)

# Convert the Term-Document Matrix into a standard matrix format
m <- as.matrix(dtm)

# Compute word frequencies by summing occurrences across all documents
word_freqs <- sort(rowSums(m), decreasing = TRUE)

# Convert the frequency data into a data frame for visualization
word_freq_table <- data.frame(word = names(word_freqs), freq = word_freqs)

# Generate a word cloud visualization with a vintage color palette
wordcloud(words = word_freq_table$word,    # Words to be displayed
          freq = word_freq_table$freq,     # Corresponding word frequencies
          min.freq = 1,                    # Minimum frequency to be displayed
          scale = c(5, 0.5),               # Scale range for word sizes (largest and smallest)
          max.words = 100,                 # Maximum number of words to display
          colors = c("#6f4f37", "#c5a880", "#b0a8b9", "#e2b97f", "#7e7f6d", 
                     "#d4a1c2", "#ce8f57", "#e7d8c9", "#cc6f39"))  # Custom vintage colors
# Out:
# plot without title
